# %% [markdown]
# Name: Vaidurya Samaga
#
#
# SRN: PES2UG23CS668

# %%
# !pip install -q transformers torch

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
bert_model = "bert-base-uncased"
roberta_model = "roberta-base"
bart_model = "facebook/bart-base"

# %% [markdown]
# EXPERIMENT-1: TEXT GENERATION

# %%
prompt = "The future of Artificial Intelligence is"

# %%
gen_bert=pipeline("text-generation", model=bert_model)
print("BERT Output:")
print(gen_bert(prompt, max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# BERT Output:
# [{'generated_text': 'The future of Artificial Intelligence is................................................................................................................................................................................................................................................................'}]

# %%
gen_roberta=pipeline("text-generation",model=roberta_model)
print("\nRoBERTa Output:")
print(gen_roberta(prompt, max_length=30))
# Out:
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# RoBERTa Output:
# [{'generated_text': 'The future of Artificial Intelligence is'}]

# %%
gen_bart=pipeline("text-generation", model=bart_model)
print("\nBART Output:")
print(gen_bart(prompt, max_length=30))
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# Some weights of BartForCausalLM were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['lm_head.weight', 'model.decoder.embed_tokens.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# BART Output:
# [{'generated_text': 'The future of Artificial Intelligence is incomprehensible STARTourgeourgeistanasis vapoxinbag exhibitionintageoplan exhibitionintage Client exhibition Yoshnearhemat exhibitionNMourgeourgeEthourgeourgeregorourgeourgeinterestinginteresting adequately Priestourgeasisasis ruthagogourge tidourgeinteresting exhibition exhibition crimourge Drill mortgages mortgagesudedourge mortgagesreader Café CaféintageourgeourgeDesktopasisintage vapourgeourge Bedfordasisasis mortgagesourgeourge coughputedintage adequatelyourgereaderrorsSimple inertiareaderealing Caféealingreally theologhemathematinterestinginterestinginterestingreader Bedfordreader Café theolognear Caféhemat Café sponsored Sanctuarybushrors theologreaderSimple Cafénearnearrors theologrorsreaderreaderreaderoxin exhibitionreaderealingealing Personsrors||||reader sensoryreaderreaderealingourge vandalreadernearnearoxinputed Brandonreaderinterestingoxinreaderreaderrorsrorsnear revolutionaryputed revolutionaryealingealing ShoealingreallyealingreaderSkealingrorsrors theolognear tuneealingealingasisrors theologealing revolutionary revolutionaryhesealingealingealing sponsorednearealingealingrors378LABreaderSk cowsSimplerors mouths Dracula revolutionary cows Forkasis theologealingreaderealingputed378 descriptSkealingealing mouthsreallyreallyreaderealingishment mouthsealingealingDISealingealingreallyreallyDIS mouths revolutionary mouths tune mood sponsored populationsealing378SkLAB PersonsSimple revolutionaryealing revolutionary disrupted Draculaealing revolutionarynear revolutionarySkealing mouthsemalenear cowsealingSknearealingnearnear recallingishmentealingllerealing'}]

# %% [markdown]
# **BERT**- fails to generate;
# **RoBERTa**- fails to generate;
# **BART**- performs text generation
#
# BERT and RoBERTa are encoder-only models which do not perform the task of generating next tokens.
# BART is an encoder-decoder model trained for generation.

# %% [markdown]
# EXPERIMENT-2: MASKED LANGUAGE MODELING

# %%
sentence1 = "The goal of Generative AI is to [MASK] new content."

# %%
fill_bert = pipeline("fill-mask", model=bert_model)
print("BERT:")
print(fill_bert(sentence1))
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# BERT:
# [{'score': 0.5396937131881714, 'token': 3443, 'token_str': 'create', 'sequence': 'the goal of generative ai is to create new content.'}, {'score': 0.15575705468654633, 'token': 9699, 'token_str': 'generate', 'sequence': 'the goal of generative ai is to generate new content.'}, {'score': 0.05405480042099953, 'token': 3965, 'token_str': 'produce', 'sequence': 'the goal of generative ai is to produce new content.'}, {'score': 0.04451539367437363, 'token': 4503, 'token_str': 'develop', 'sequence': 'the goal of generative ai is to develop new content.'}, {'score': 0.01757744885981083, 'token': 5587, 'token_str': 'add', 'sequence': 'the goal of generative ai is to add new content.'}]

# %%
sentence2 = "The goal of Generative AI is to <mask> new content."

# %%
fill_roberta = pipeline("fill-mask", model=roberta_model)
print("\nRoBERTa:")
print(fill_roberta(sentence2))
# Out:
# Device set to use cpu
# RoBERTa:
# [{'score': 0.37113314867019653, 'token': 5368, 'token_str': ' generate', 'sequence': 'The goal of Generative AI is to generate new content.'}, {'score': 0.36771294474601746, 'token': 1045, 'token_str': ' create', 'sequence': 'The goal of Generative AI is to create new content.'}, {'score': 0.08351416140794754, 'token': 8286, 'token_str': ' discover', 'sequence': 'The goal of Generative AI is to discover new content.'}, {'score': 0.02133510820567608, 'token': 465, 'token_str': ' find', 'sequence': 'The goal of Generative AI is to find new content.'}, {'score': 0.016521671786904335, 'token': 694, 'token_str': ' provide', 'sequence': 'The goal of Generative AI is to provide new content.'}]

# %%
fill_bart = pipeline("fill-mask", model=bart_model)
print("\nBART:")
print(fill_bart(sentence2))
# Out:
# Device set to use cpu
# BART:
# [{'score': 0.0746152326464653, 'token': 1045, 'token_str': ' create', 'sequence': 'The goal of Generative AI is to create new content.'}, {'score': 0.06571866571903229, 'token': 244, 'token_str': ' help', 'sequence': 'The goal of Generative AI is to help new content.'}, {'score': 0.060880016535520554, 'token': 694, 'token_str': ' provide', 'sequence': 'The goal of Generative AI is to provide new content.'}, {'score': 0.03593575954437256, 'token': 3155, 'token_str': ' enable', 'sequence': 'The goal of Generative AI is to enable new content.'}, {'score': 0.03319466486573219, 'token': 1477, 'token_str': ' improve', 'sequence': 'The goal of Generative AI is to improve new content.'}]

# %% [markdown]
# BERT-Predicts the masked word; RoBERTa-predicts the masked word more accurately; BART- does not perform well in predicting the masked word
#
# BERT and RoBERTa are trained mainly on Masked Language Modeling. BART focuses on sentence-level reconstruction and not on single masked tokens.

# %% [markdown]
# EXPERIMENT-3: QUESTION ANSWERING

# %%
context = "Generative AI poses significant risks such as hallucinations, bias, and deepfakes."
question = "What are the risks?"

# %%
qa_bert=pipeline("question-answering",model=bert_model)
print("BERT:")
print(qa_bert(question=question, context=context))
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# BERT:
# {'score': 0.01336853438988328, 'start': 46, 'end': 60, 'answer': 'hallucinations'}

# %%
qa_roberta = pipeline("question-answering", model=roberta_model)

print("\nRoBERTa QA:")
print(qa_roberta(question=question, context=context))
# Out:
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# RoBERTa QA:
# {'score': 0.003870239946991205, 'start': 11, 'end': 37, 'answer': 'AI poses significant risks'}

# %%
qa_bart = pipeline("question-answering", model=bart_model)

print("\nBART QA:")
print(qa_bart(question=question, context=context))
# Out:
# Some weights of BartForQuestionAnswering were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# BART QA:
# {'score': 0.020778173580765724, 'start': 38, 'end': 67, 'answer': 'such as hallucinations, bias,'}

# %% [markdown]
# All the models produce weak and inconsistent answers.
# QA requires task-specific fine-tuning, not just architecture

# %% [markdown]
# | Task | Model | Classification (Success/Failure) | Observation (What actually happened?) | Why did this happen? (Architectural Reason) |
# |----|----|----|----|----|
# | Text Generation | BERT | Failure | Produced gibberish / repeated prompt | BERT is an encoder-only model does not perform the task of generating  next tokens |
# | Text Generation | RoBERTa | Failure | Failed similarly to BERT | RoBERTa is also encoder-only and not trained for generation of next tokens |
# | Text Generation | BART | Success | Generated coherent continuation | BART is an encoder-decoder model which has a decoder trained for text generation |
# | Fill-Mask | BERT | Success | Predicted words like “create”, “generate” | BERT was trained on Masked Language Modeling |
# | Fill-Mask | RoBERTa | Success | more accurate predictions of masked words | RoBERTa is also trained on Masked Language Modeling|
# | Fill-Mask | BART | Partial / Failure | Less accurate predictions | BART focuses on sentence reconstruction, not token masking |
# | QA | BERT | Partial / Failure | Weak or random answer | Model not fine-tuned for QA tasks |
# | QA | RoBERTa | Partial / Failure | Inconsistent results | Requires QA fine-tuning  |
# | QA | BART | Partial / Failure | Unreliable answer | QA requires task-specific training |
